# %% [markdown]
# # Demo de funciones AEMET
#
# Este notebook carga las funciones del paquete y muestra lo que devuelven.
#
# > Configura tu API key en la variable de entorno `AEMET_API_KEY` antes de ejecutar.

# %% [markdown]
# ## 1. Import Required Libraries and Load Functions

# %%
import os

API_KEY = ("eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0")
if not API_KEY:
    print("⚠️ Falta AEMET_API_KEY. Define la variable de entorno para ejecutar los ejemplos.")

# %%
import asyncio
from datetime import datetime, timedelta
import pandas as pd

# %% [markdown]
# ## 2. Avisos

# %%
from aemetdata.avisos import avisos_area_ultimo_eleaborado
ruta = await avisos_area_ultimo_eleaborado("72", [API_KEY])
print(f"Archivo guardado: {ruta}")
# Out:
# 🔍 Solicitando avisos para área 72 (Madrid, Comunidad de)
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# Probando endpoint: https://opendata.aemet.es/opendata/api/avisos_cap/ultimoelaborado/area/72?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0
# ✔️ Datos obtenidos con la clave 1.
# ✨ Descargando archivo tar.gz de avisos CAP desde URL de AEMET
# Archivo guardado: avisos_area_72_20260218122632.tar.gz

# %%
# Descargar archivos tar.gz de avisos por fechas
from aemetdata.avisos import avisos_por_fechas
rutas = await avisos_por_fechas('2026-01-01', '2026-01-04', [API_KEY])
print('Archivos guardados:')
for ruta in rutas:
    print(ruta)
# Out:
# 🔍 Solicitando avisos CAP desde 2026-01-01T00:00:00UTC a 2026-01-02T23:59:59UTC
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# Probando endpoint: https://opendata.aemet.es/opendata/api/avisos_cap/archivo/fechaini/2026-01-01T00:00:00UTC/fechafin/2026-01-02T23:59:59UTC?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0
# ✔️ Datos obtenidos con la clave 1.
# ✨ Descargando archivo tar.gz de avisos CAP desde URL de AEMET
# 🔍 Solicitando avisos CAP desde 2026-01-03T00:00:00UTC a 2026-01-04T23:59:59UTC
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# ...

# %% [markdown]
# ## 3. Climatología

# %% [markdown]
# ### 3.1 Climatología mensual

# %%
from aemetdata.climatologia import datos_mensuales
resultado = await datos_mensuales(["3195","3427Y"], 2020, 2024, [API_KEY])
print(f"Tipo: {type(resultado)}")
pd.DataFrame(resultado)
# Out:
# 🔍 Solicitando climatología mensual para estación 3195 entre 2020 y 2022
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# Probando endpoint: https://opendata.aemet.es/opendata/api/valores/climatologicos/mensualesanuales/datos/anioini/2020/aniofin/2022/estacion/3195?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0
# ✔️ Datos obtenidos con la clave 1.
# ✨ Descargando datos de climatología mensual desde URL de AEMET: https://opendata.aemet.es/opendata/sh/fa7a45fc
# 📥 Descargando JSON desde: https://opendata.aemet.es/opendata/sh/fa7a45fc
# ✅ Datos de climatología mensual descargados exitosamente para estación 3195
# 🔍 Solicitando climatología mensual para estación 3195 entre 2023 y 2024
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# ...

# %% [markdown]
# ### 3.2 Climatología diaria

# %%
from aemetdata.climatologia import datos_diarios
# Ejemplo: dos estaciones, rango de fechas (solo AAAA-MM-DD)
resultado = await datos_diarios(["3195","3427Y"], '2022-01-01', '2022-08-10', [API_KEY])
print(f'Tipo: {type(resultado)}')
pd.DataFrame(resultado)
# Out:
# 🔍 Solicitando climatología diaria para estación 3195 entre 2022-01-01T00:00:00UTC y 2022-06-30T23:59:59UTC
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# Probando endpoint: https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2022-01-01T00:00:00UTC/fechafin/2022-06-30T23:59:59UTC/estacion/3195?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0
# ✔️ Datos obtenidos con la clave 1.
# ✨ Descargando datos de climatología diaria desde URL de AEMET: https://opendata.aemet.es/opendata/sh/6aa70e3e
# 📥 Descargando JSON desde: https://opendata.aemet.es/opendata/sh/6aa70e3e
# ✅ Datos de climatología diaria descargados exitosamente para estación 3195
# ...

# %% [markdown]
# ### 3.3 Valores normales
# Valores climatológicos normales (periodo 1991-2020) para la estación pasada por parámetro. Periodicidad: 1 vez al día.

# %%
from aemetdata.climatologia import datos_normales

# Valores normales
resultado_normales = await datos_normales(["3195","3427Y"], [API_KEY])
print(f"Tipo: {type(resultado_normales)}")
import pandas as pd
pd.DataFrame(resultado_normales)
# Out:
# 🔍 Solicitando valores normales para estación 3195
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# Probando endpoint: https://opendata.aemet.es/opendata/api/valores/climatologicos/normales/estacion/3195?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0
# ✔️ Datos obtenidos con la clave 1.
# ✨ Descargando valores normales desde URL de AEMET: https://opendata.aemet.es/opendata/sh/37f2e524
# 📥 Descargando JSON desde: https://opendata.aemet.es/opendata/sh/37f2e524
# ✅ Valores normales descargados exitosamente para estación 3195
# 🔍 Solicitando valores normales para estación 3427Y
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# ...

# %% [markdown]
# ### 3.4 Valores extremos
# Valores extremos para la estación  (precipitación, temperatura y viento). Periodicidad: 1 vez al día.

# %%
from aemetdata.climatologia import datos_extremos


# Valores extremos con parámetro personalizado
resultado_extremos_T = await datos_extremos(["3195","3427Y"], [API_KEY], parametro="T")
print(f"Tipo: {type(resultado_extremos_T)}")
pd.DataFrame(resultado_extremos_T)
# Out:
# 🔍 Solicitando valores extremos para estación 3195, parámetro T
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# Probando endpoint: https://opendata.aemet.es/opendata/api/valores/climatologicos/valoresextremos/parametro/T/estacion/3195?api_key=eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJjcGFjaGVjby5wZXJlbGxvQGdtYWlsLmNvbSIsImp0aSI6IjE2ZGQxZjJlLTJkMWYtNGI3NS1hYjQ0LWEzNTNhNmQyMjU0NiIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNzY4MzgzMjcwLCJ1c2VySWQiOiIxNmRkMWYyZS0yZDFmLTRiNzUtYWI0NC1hMzUzYTZkMjI1NDYiLCJyb2xlIjoiIn0.4eP7KwIbUfdq91ZrcPYEwPhUgPN1sUhCyIZdrieHnc0
# ✔️ Datos obtenidos con la clave 1.
# ✨ Descargando valores extremos desde URL de AEMET: https://opendata.aemet.es/opendata/sh/7a0ff521
# 📥 Descargando JSON desde: https://opendata.aemet.es/opendata/sh/7a0ff521
# ✅ Valores extremos descargados exitosamente para estación 3195, parámetro T
# 🔍 Solicitando valores extremos para estación 3427Y, parámetro T
# Accediendo Base datos AEMET
# 🔄 Ciclo 1 de 3
# ...
